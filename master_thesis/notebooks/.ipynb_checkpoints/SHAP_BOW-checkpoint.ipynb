# %%
import pandas as pd
import numpy as np
import json
from pathlib import Path

import spacy
import nltk
nltk.download('stopwords')

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer


import scipy.stats as st
from sklearn.metrics import mean_absolute_error, mean_squared_error

import matplotlib.pyplot as plt

from master_thesis.src import utils

pd.set_option('display.max_columns', 80) # make all columns visible
import xgboost
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ruecker/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pickle
import shap

shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %% [markdown]
# ## BOW

# %%
# loading model with pickle
feature_type = "abs"
publisher = "NOZ"
vectorizer_type = "CountVectorizer"



# das hier für xgboost
classifier = "xgboost"

##max_features = 100000 # etwas besser, dafür mit Stopwörtern dabei...
##preprocessing = "FalseTrueTrue"

max_features = 10000 # etwas schlechter, dafür ohne Stopwörter
preprocessing = "TrueTrueTrue"
##preprocessing = "FalseFalseTrue"

# das hier für ridge
#max_features = 1000
#classifier = "ridge"
#preprocessing = "TrueTrueTrue"




identifier = f'BOW_{vectorizer_type}_{classifier}_{feature_type}_{str(max_features)}_{preprocessing}.pkl'
print(identifier)

model_PATH = utils.OUTPUT / 'saved_models' / identifier

with open(model_PATH, 'rb') as p_in:
    model = pickle.load(p_in)
# Out:
# BOW_CountVectorizer_xgboost_abs_10000_TrueTrueTrue.pkl

# %%
model
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.1, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=300, n_jobs=32, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
# loading features

print("loading features...", feature_type)
X_train = np.load(utils.OUTPUT / 'BOW_features' / f'{vectorizer_type}_{publisher}_X_train_{feature_type}_{str(max_features)}_{preprocessing}.npy')
X_dev = np.load(utils.OUTPUT / 'BOW_features' / f'{vectorizer_type}_{publisher}_X_dev_{feature_type}_{str(max_features)}_{preprocessing}.npy')
X_test = np.load(utils.OUTPUT / 'BOW_features' / f'{vectorizer_type}_{publisher}_X_test_{feature_type}_{str(max_features)}_{preprocessing}.npy')

print(X_train.shape, X_dev.shape, X_test.shape)
# Out:
# loading features... abs
# (29106, 10000) (3638, 10000) (3639, 10000)

# %%
modeltype = "xgboost"
#modeltype = "ridge"

print(modeltype)

# ridge
if modeltype == "ridge":
    explainer = shap.LinearExplainer(model, X_train)
    shap_values = explainer.shap_values(X_dev)

# xgboost
if modeltype == "xgboost":
    #explainer = shap.KernelExplainer(model.predict, X_dev[:100])
    #shap_values = explainer.shap_values(X_dev[:100])
    
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_dev)
    
    #explainer = shap.TreeExplainer(model, X_train) # mit oder ohne (, X_train) ??
    #shap_values = explainer.shap_values(X_dev) # explainer.shap_values(X_dev)
    #shap_values = explainer(X_dev) # für manche plots ist das nötig, für andere das drüber...
# Out:
# xgboost

# %%
shap_values.shape
# Out:
# (3638, 10000)

# %%
import pickle

shap_PATH = utils.OUTPUT / 'shap_values' / f'BOW_{vectorizer_type}_{classifier}_{feature_type}_{str(max_features)}_{preprocessing}_shap_values.pkl'

#with open(shap_PATH, 'wb') as p_out:
#    pickle.dump(shap_values, p_out, pickle.HIGHEST_PROTOCOL)

with open(shap_PATH, 'rb') as p_in:
    shap_values = pickle.load(p_in)

# %%
len(shap_values[0])
# Out:
# 10000

# %%
# loading vectorizer and feature_names

with open(utils.OUTPUT / 'BOW_features' / f'{vectorizer_type}_{publisher}_vectorizer_{str(max_features)}_{preprocessing}.pkl', 'rb') as fp:
    vectorizer = pickle.load(fp)
    
feature_names = vectorizer.get_feature_names()
print(len(feature_names))
# Out:
# 10000

# %%
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=10000, min_df=5,
#                 ngram_range=(1, 4),
#                 preprocessor=<master_thesis.src.utils.Preprocessor object at 0x7f6864ffda10>,
#                 stop_words=None, strip_accents=None,
#                 token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None,
#                 vocabulary=None)

# %%
feature_names[657]#[100:120] # find the name of a feature
# Out:
# 'alleinerziehende'

# %%
feature_names[500:530]
# Out:
# ['ablehnen',
#  'ablehnung',
#  'abliefern',
#  'ablösen',
#  'abnehmen',
#  'abnehmer',
#  'abo',
#  'abreißen',
#  'abriss',
#  'abrufen',
#  'absage',
#  'absagen',
#  'absatz',
#  'abschaffen',
#  'abschaffung',
#  'abschalten',
#  'abschied',
#  'abschleppen',
#  'abschließen',
#  'abschließen sein',
#  'abschließend',
#  'abschluss',
#  'abschneiden',
#  'abschnitt',
#  'absehbar',
#  'absehbar zeit',
#  'absehen',
#  'abseits',
#  'absetzen',
#  'absichern']

# %%
prep0 = utils.Preprocessor(delete_stopwords=False, lemmatize=False, delete_punctuation=True)
prep1 = utils.Preprocessor(delete_stopwords=False, lemmatize=True, delete_punctuation=True)
prep2 = utils.Preprocessor(delete_stopwords=True, lemmatize=False, delete_punctuation=True)
prep3 = utils.Preprocessor(delete_stopwords=True, lemmatize=True, delete_punctuation=True)

# %%
print(prep0("Ich finde die Lockerungen sind eine interessante Maßnahme. Und du?"))
print(prep1("Ich finde die Lockerungen sind eine interessante Maßnahme. Und du?"))
print(prep2("Ich finde die Lockerungen sind eine interessante Maßnahme. Und du?"))
print(prep3("Ich finde die Lockerungen sind eine interessante Maßnahme. Und du?"))
# Out:
# ich finde die lockerungen sind eine interessante maßnahme und du
# ich finden der lockerungen sein einen interessante maßnahme und du
# finde lockerungen interessante maßnahme
# finden lockerungen sein interessante maßnahme

# %%
#feature_names.index("sind") # "sind" not there (becaus lemmatization!)
feature_names.index("sein")
feature_names.index("alle")
# Out:
# 648

# %%
feature_names.index("der") # see if stop wrds are in or not
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-343-6af445556b0c> in <module>
# ----> 1 feature_names.index("der") # see if stop wrds are in or not
#
# ValueError: 'der' is not in list

# %%
import spacy
nlp = spacy.load("de_core_news_sm", disable=['parser', 'ner'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-932-e04b0a8184ae> in <module>
#       1 import spacy
# ----> 2 nlp = spacy.load("de_core_news_sm", disable=['parser', 'ner'])
#
# ~/miniconda3/envs/GPU/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
#      29         warnings.warn(Warnings.W001.format(path=depr_path), DeprecationWarning)
# ---> 30     return util.load_model(name, **overrides)
#      31
#      32
#
# ~/miniconda3/envs/GPU/lib/python3.7/site-packages/spacy/util.py in load_model(name, **overrides)
#     168             return load_model_from_link(name, **overrides)
#     169         if is_package(name):  # installed as package
# --> 170             return load_model_from_package(name, **overrides)
#     171         if Path(name).exists():  # path to model data directory
# ...

# %%
nlp("alles")[0].lemma_ # aaaaaah!

# %%
nlp("alle")[0].lemma_
# Out:
# 'all'

# %%
feature_names.index("statt") # search for a specific token
# Out:
# 8179

# %%
feature_names.index("foto") # search for a specific token
# Out:
# 3339

# %%
#shap.summary_plot(shap_values, X_dev, feature_names = feature_names)
#shap.summary_plot(shap_values, X_dev[:100], feature_names = feature_names)
shap.summary_plot(shap_values, features=X_dev, feature_names=feature_names, max_display=30)

# %%
type(shap_values)
# Out:
# numpy.ndarray

# %%
shap_values.shape
# Out:
# (3638, 10000)

# %%
shap.dependence_plot("foto", shap_values, X_dev, feature_names = feature_names)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
# hier mal devDaten laden und Text azeigen lassen?
NOZ = utils.get_publisher_df("NOZ")
# Out:
# Shape of df: (36383, 31)

# %%
with open(utils.OUTPUT / "splits" / f"NOZ_splits.json", "r") as f:
    splits = json.load(f)
    dev_IDs = splits["dev"]

# %%
dev_IDs[:10] # das ist die Reihenfolge in den shap_values
# Out:
# ['NOZ_2093706',
#  'NOZ_1990893',
#  'NOZ_2053403',
#  'NOZ_2093781',
#  'NOZ_2133782',
#  'NOZ_2039028',
#  'NOZ_2008155',
#  'NOZ_1988194',
#  'NOZ_2060578',
#  'NOZ_2040020']

# %%
i = 47
ID = dev_IDs[47]
print(ID)
shap.force_plot(explainer.expected_value, shap_values[i], features=X_dev[i], feature_names=feature_names)
# Out:
# NOZ_2058263
# <div id='iR0AK5XP2MEWC2FNHUFW2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
NOZ.loc[ID].article_text
# Out:
# 'Zu viele Fälle, zu viele Tote: Nachbarstaaten skeptisch: Müssen die Schweden draußen bleiben? Stockholm. Wegen Schwedens lockerem Corona-Kurs gibt es in den nordischen Nachbarländern Bedenken, bei Grenzwiederöffnungen schwedische Touristen ins Land zu lassen. Deutsche seien dahingegen willkommen, heißt es etwa aus Dänemark. Schweden fährt einen Sonderweg in der Corona-Krise. Fast alles blieb und bleibt geöffnet. So soll auch schneller Herdenimmunität erreicht werden. Wenn möglichst viele das Virus einmal in sich hatten und dadurch immun geworden sind, breitet es sich nicht mehr so schnell aus, etwa zu Risikogruppen, für die eine Ansteckung im schlimmsten Fall tödlich sein kann, so der Gedanke mit der Herdenimmunität. Mehr zum Thema: Wegen Schwedens vermeintlich unvorsichtigem Sonderweg regen sich nun aber in den nordischen Nachbarländern, die wie Deutschland und Österreich auf strikte Verbote statt Freiwilligkeit setzten, Bedenken bei Grenzwiedereröffnungen in diesem Sommer auch sch
# ...

# %%
#shap_values[i]

# %%
# ein bestimmtes Feature (token) anschauen:

token = "sein" #"foto"#"osnabrück" #"sein" #"osnabrück" #"sein" #"heute" #"osnabrück" #"corona" #"foto"
token_id = feature_names.index(token) # search for a specific token
print(f"Dast Token \"{token}\" ist an der Stelle: \n{token_id}")
# Out:
# Dast Token "sein" ist an der Stelle:
# 7478

# %%
shap_values[:, token_id][:20] # 
# die ersten 20 Dokumente und der shap_value für das bestimmte Token
# Out:
# array([ -0.24206813,   6.5534477 , -16.275957  ,  -3.7146194 ,
#        -21.744656  ,  21.71508   , -13.768895  ,   5.32895   ,
#          0.44665158,  43.084072  ,   1.4566084 ,  20.828682  ,
#         -6.5255384 , -17.933329  ,  10.291361  , -22.843203  ,
#         17.714867  ,  10.473898  ,  -8.5704975 , -21.023254  ],
#       dtype=float32)

# %%
X_dev[:, token_id][:20]
# die absoluten counts von Token in den ersten 20 Dokumenten
# Out:
# array([ 9, 10,  2,  7,  0, 22,  5, 11,  8, 24,  8, 14,  6,  1, 16,  3, 22,
#        10,  6,  1])

# %%
np.mean(shap_values[:, token_id])
# Out:
# 0.86636674

# %%
#print(np.mean(shap_values[:, token_id].values)) # mean shap_value for one token/feature
#print(np.mean(abs(shap_values[:, token_id].values))) # mean (abs!) shap_value for one token/feature

print(np.mean(shap_values[:, token_id])) # mean shap_value for one token/feature
print(np.mean(abs(shap_values[:, token_id]))) # mean (abs!) shap_value for one token/feature
# Out:
# 0.86636674
# 16.454596

# %%
#plt.hist(shap_values[:, token_id], 200)
#plt.xlim(-20,20)
#plt.show()

# %%
f = {'size': 24,
            }

plt.figure(figsize=(8,6))

plt.scatter(X_dev[:, token_id], shap_values[:, token_id], alpha = 0.5)
plt.xlabel(f"Absolute Anzahl von \'{token}\' im Artikel", labelpad = 10.0, fontdict = f)
plt.xticks(fontsize=14)
plt.ylabel("Shapley-Wert", fontdict = f)
plt.yticks(fontsize=14)


plt.xlim(-1, 51)
plt.ylim(-50, 100)


plt.tight_layout()
#plt.show()

plt.savefig(f'xgboost{token}.jpg', dpi = 150)

# %%
# im Wesentlichen das gleiche wie:
# dauert nur lange
#shap.dependence_plot(f"{token}", shap_values, X_dev, feature_names=feature_names)

# %%
# was sollte das hier?
#plt.scatter(shap_values[:, token_id].data, shap_values[:, 346], alpha = 0.2)

# %%
shap.plots.bar(shap_values)#, feature_names = feature_names)
# das zeigt den mean ABS value über die Dokumente! Also zum Bsp. "corona" hat sowohl negative als auch positive shap_values, 
# hier ist aber die abs gemittelt und daher der Wert größer als er ohne abs wäre
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-43-e56edc6fdea1> in <module>
# ----> 1 shap.plots.bar(shap_values)#, feature_names = feature_names)
#       2 # das zeigt den mean ABS value über die Dokumente! Also zum Bsp. "corona" hat sowohl negative als auch positive shap_values,
#       3 # hier ist aber die abs gemittelt und daher der Wert größer als er ohne abs wäre
#
# ~/miniconda3/envs/GPU/lib/python3.7/site-packages/shap/plots/_bar.py in bar(shap_values, max_display, order, clustering, cluster_threshold, show)
#      39     """
#      40
# ---> 41     assert str(type(shap_values)).endswith("Explanation'>"), "The shap_values paramemter must be a shap.Explanation object!"
#      42
#      43     if len(shap_values.shape) == 2:
#
# AssertionError: The shap_values paramemter must be a shap.Explanation object!

# %%
shap.plots.beeswarm(shap_values)#, feature_names = feature_names)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-44-de99b5109602> in <module>
# ----> 1 shap.plots.beeswarm(shap_values)#, feature_names = feature_names)
#
# ~/miniconda3/envs/GPU/lib/python3.7/site-packages/shap/plots/_beeswarm.py in beeswarm(shap_values, max_display, color, feature_order, axis_color, alpha, show, log_scale, color_bar, plot_size, color_bar_label)
#      71     # default color:
#      72     if color is None:
# ---> 73         if features is not None:
#      74             color = colors.red_blue
#      75         else:
#
# UnboundLocalError: local variable 'features' referenced before assignment

# %%
shap.plots.waterfall(shap_values[0]) # one prediction
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-1b78ba9cae95> in <module>
# ----> 1 shap.plots.waterfall(shap_values[0]) # one prediction
#
# ~/miniconda3/envs/GPU/lib/python3.7/site-packages/shap/plots/_waterfall.py in waterfall(shap_values, max_display, show)
#      40
#      41
# ---> 42     base_values = shap_values.base_values
#      43
#      44     features = shap_values.data
#
# AttributeError: 'numpy.ndarray' object has no attribute 'base_values'

# %%
feature_names[1111]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-ef742b93ae37> in <module>
# ----> 1 feature_names[1111]
#
# IndexError: list index out of range

# %%
shap_values[0].data[1111]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-5ecceef70a2c> in <module>
# ----> 1 shap_values[0].data[1111]
#
# IndexError: index out of bounds on dimension 1

# %%
shap_values[0].values[1111]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-4867b8d230e5> in <module>
# ----> 1 shap_values[0].values[1111]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
dev_preds.article_text[0][:500]
# Out:
# 'Initiative "Grün statt Grau" übt Kritik: Das grüne Gewerbegebiet in Melle ist "nicht grün genug" Melle. Nachhaltig, ökologisch, zukunftsfähig: So soll das 18 Hektar große Gewerbegebiet in Melle zwischen Gesmolder Straße, Am Fuhlenkamp, Kirchbreedeweg und der A30 nach dem Willen der Stadt und der Bürgerinitiative "Grün statt Grau" konzipiert werden. Die bisherigen Bemühungen der Kommune gehen der Initiative allerdings nicht weit genug. Sie verlangt Nachbesserungen. "Der erste Entwurf des Bebauung'

# %%
shap.force_plot(explainer.expected_value[0], shap_values[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-271-3218baa35e23> in <module>
# ----> 1 shap.force_plot(explainer.expected_value[0], shap_values[0])
#
# IndexError: invalid index to scalar variable.

# %%
shap.summary_plot(shap_values, X_dev, feature_names=feature_names, max_display = 25)

# %%
xgboost.plot_importance(model, max_num_features = 12,
                       importance_type ="weight") # "weight" "gain" cover"
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
feature_names[38]
# Out:
# '45'

# %%
feature_names[390]
# Out:
# 'gerne'

# %%
shap.summary_plot(shap_values, X_dev, plot_type="bar", feature_names=feature_names)

# %%
ind = 0
shap.force_plot(explainer.expected_value,
                shap_values[ind,:],
                X_dev[ind,:],
                feature_names=feature_names
               )
# Out:
# <div id='i3GW7MR9KXR5SK8AT861S'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
explainer.expected_value
# Out:
# 185.77997

# %%
shap_values[0] # Doc 0, length is 10000
# Out:
# array([ 1.35301948e+00, -2.58976477e-03, -9.59219187e-02, -4.67274994e-01,
#         2.76680887e-01,  2.79454654e-03,  7.97838345e-02,  1.87471751e-02,
#         3.86095978e-02,  1.12975324e-02,  3.40785868e-02,  2.30970141e-02,
#         8.49019468e-01,  1.40701467e-02, -3.73018458e-02,  2.26875935e-02,
#        -1.08798705e-01, -1.22972466e-01,  4.63666068e-03,  9.78886113e-02,
#         5.59791982e-01,  1.15468872e+00,  1.26928231e-02, -8.64709436e-04,
#        -3.34824785e-03,  4.19284590e-02, -1.06388917e-02,  2.06074286e-02,
#         4.98507591e-03, -8.66375025e-03, -2.48445343e-04,  4.67514060e-03,
#        -3.40234898e-02,  8.33029579e-03, -1.11179203e-01, -3.47425304e-02,
#        -3.95712778e-02, -8.31484515e-03, -1.49963543e-01, -1.37853533e-01,
#        -5.97659387e-02,  6.64651021e-02, -1.87387236e-03, -1.72901712e-02,
#        -4.52075042e-02, -8.14699948e-01,  2.14635837e-03,  7.51867774e-04,
# ...

# %%
feature_names.index("maske")
# Out:
# 5672

# %%
shap_values[:, 5672]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %% [markdown]
# ## vergleichbar zu bei BERT: selber values speichern und betrachten!

# %%
df_shap = pd.DataFrame(index=feature_names, columns = ["count", "mean", "mean_abs", "min", "max", "std"])

# %%
df_shap.head()
# Out:
#          count mean mean_abs  min  max  std
# 000        NaN  NaN      NaN  NaN  NaN  NaN
# 000 euro   NaN  NaN      NaN  NaN  NaN  NaN
# 10         NaN  NaN      NaN  NaN  NaN  NaN
# 100        NaN  NaN      NaN  NaN  NaN  NaN
# 1000       NaN  NaN      NaN  NaN  NaN  NaN

# %%
df_shap.shape
# Out:
# (1000, 6)

# %%
# getting mean shap_value and count of the frequent tokens
for nr_feature, feature in enumerate(feature_names):
    print(nr_feature, feature, end="\r")
    values = shap_values[:, nr_feature] # all the shap values for the token
    count = np.sum(X_dev[:, nr_feature]) # das zählt Vorkommen (also auch mehrmals im gleichen Text)
    mean = np.mean(values)
    mean_abs = np.mean(abs(np.array(values)))
    min_value = np.min(values)
    max_value = np.max(values)
    std = np.std(values)
    df_shap.loc[feature]["mean"] = mean.round(3)
    df_shap.loc[feature]["mean_abs"] = mean_abs.round(3)
    df_shap.loc[feature]["count"] = count
    df_shap.loc[feature]["min"] = min_value.round(3)
    df_shap.loc[feature]["max"] = max_value.round(3)
    df_shap.loc[feature]["std"] = std.round(3)

    #if nr_feature >=10:
    #    break
# Out:
# 999 überzeugenngiteaftk

# %%
df_shap["abs"] = abs(df_shap["mean"])

# %%
df_shap.head(20)
# Out:
#          count   mean mean_abs     min      max    std    abs
# 000       1097  0.001    0.057  -1.959    0.034  0.105  0.001
# 000 euro   586  0.009    0.421 -24.839    0.233  1.036  0.009
# 10         538 -0.036    1.146  -0.656   137.77  3.181  0.036
# 100        460      0        0  -0.001        0      0      0
# 1000       183 -0.004    0.113  -5.958    0.057  0.341  0.004
# 11         406 -0.006    0.359  -0.195   74.625  1.617  0.006
# 12         365 -0.029    0.306   -0.18   13.335  0.703  0.029
# 13         535  0.002    0.193 -23.974    0.106  0.613  0.002
# 14         609  0.005    0.145  -0.079   15.933   0.39  0.005
# 15         749  0.007    0.266 -10.319    0.161  0.456  0.007
# 16         513 -0.002    0.178 -11.986    0.098  0.399  0.002
# 17         488     -0    0.039  -1.779    0.022  0.088      0
# 18         626  0.003    0.226  -6.505     0.13  0.437  0.003
# 19         641  0.004      0.4 -15.037    0.229  0.839  0.004
# ...

# %%
shap.summary_plot(shap_values, X_dev, plot_type="bar", feature_names=feature_names)

# %%
tmp = df_shap[df_shap["count"] >= 200].sort_values("mean_abs", ascending = False)
tmp
# Out:
#               count   mean mean_abs      min      max     std    abs
# sein          31583  0.428    8.473  -13.513  114.957  12.224  0.428
# foto           1848  0.017    4.637 -141.382     2.95   8.388  0.017
# jahr           5543  0.234    4.252  -49.643    4.347   5.793  0.234
# corona         2520 -0.145    4.127  -75.541    2.708   6.338  0.145
# million         809 -0.135    2.521    -1.48  167.864   6.117  0.135
# ...             ...    ...      ...      ...      ...     ...    ...
# entscheidung    475     -0    0.004   -0.131    0.002    0.01      0
# legen           382     -0    0.002   -0.043    0.001   0.004      0
# erstmals        209      0    0.001       -0    0.027   0.002      0
# nachricht       215      0        0       -0    0.043   0.002      0
# 100             460      0        0   -0.001        0       0      0
#
# [760 rows x 7 columns]

# %%
tmp[["count", "mean_abs"]][:30]
# Out:
#           count mean_abs
# sein      31583    8.473
# foto       1848    4.637
# jahr       5543    4.252
# corona     2520    4.127
# million     809    2.521
# mehr       3426    2.462
# meist       468    2.432
# warum       437    2.417
# mutter      362    2.394
# rolle       271    2.375
# erst       2429    2.332
# geben      4217    2.229
# spät        756    2.218
# 2020        959    2.213
# kind       1752    2.167
# häufig      268    2.116
# hören       647    2.062
# wer         900    2.051
# halten      950    2.032
# heute       827    2.027
# polizei    1432    1.975
# ganz       1317    1.944
# frau       1117    1.921
# heißen      949    1.879
# familie     919    1.847
# etwa       1040    1.825
# zunächst    724    1.781
# stehen     2344    1.777
# tragen      469    1.708
# immer      1897     1.68

# %%
print(tmp[["count", "mean_abs"]][:20].to_latex())
# Out:
# \begin{tabular}{lll}
# \toprule
# {} &  count & mean\_abs \\
# \midrule
# sein        &  31583 &   16.455 \\
# osnabrück   &   2808 &    5.257 \\
# heute       &    827 &    2.478 \\
# geben       &   4217 &    2.138 \\
# foto        &   1848 &     1.87 \\
# meist       &    468 &    1.783 \\
# corona      &   2520 &    1.651 \\
# wer         &    900 &    1.401 \\
# etwa        &   1040 &    1.281 \\
# ab          &   1696 &     1.16 \\
# deutschland &   1141 &    0.997 \\
# neu         &   1889 &    0.983 \\
# heißen      &    949 &    0.981 \\
# million     &    809 &    0.946 \\
# liegen      &   1033 &    0.928 \\
# 2020        &    959 &    0.925 \\
# erst        &   2429 &    0.907 \\
# sagen       &   4551 &    0.883 \\
# schreiben   &    459 &    0.866 \\
# vater       &    318 &     0.81 \\
# \bottomrule
# \end{tabular}

# %%
tmp2 = df_shap[df_shap["count"] >= 200].sort_values("mean", ascending = False).head(20)
tmp2
# Out:
#                 count   mean mean_abs     min      max     std    abs
# sein            31583  0.428    8.473 -13.513  114.957  12.224  0.428
# 2018              394  0.266    1.316 -42.909    0.859   2.433  0.266
# jahr             5543  0.234    4.252 -49.643    4.347   5.793  0.234
# dpa               294  0.177    1.125 -62.081    0.685   2.936  0.177
# hören             647  0.165    2.062  -1.097   41.485   3.717  0.165
# kündigen          235  0.116    0.975  -0.453   78.901   2.841  0.116
# denken            299  0.112    1.326  -0.648   91.857   3.565  0.112
# darüber hinaus    208  0.105    1.216  -0.586   47.803   3.056  0.105
# angst             278  0.098     0.56  -0.242   62.057   2.162  0.098
# million euro      497  0.083    1.438 -68.712    0.814   3.825  0.083
# polizei          1432  0.081    1.975 -44.987    1.217   3.321  0.081
# januar            408  0.078    1.073 -71.892     0.62     2.8  0.078
# ...

# %%
print(tmp2[["count", "mean", "mean_abs"]].to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
# {} &  count &   mean & mean\_abs \\
# \midrule
# sein        &  31583 &  0.866 &   16.455 \\
# sehen       &   1589 &  0.147 &    0.595 \\
# geben       &   4217 &  0.126 &    2.138 \\
# foto        &   1848 &  0.124 &     1.87 \\
# erklären    &   1426 &   0.11 &    0.753 \\
# 100         &    460 &  0.102 &     0.17 \\
# deutschland &   1141 &   0.09 &    0.997 \\
# wer         &    900 &  0.088 &    1.401 \\
# januar      &    408 &  0.061 &    0.423 \\
# unternehmen &   1010 &  0.049 &    0.401 \\
# neu         &   1889 &  0.048 &    0.983 \\
# liegen      &   1033 &  0.047 &    0.928 \\
# 000         &   1097 &  0.041 &    0.147 \\
# tatsächlich &    267 &  0.041 &    0.756 \\
# sagen       &   4551 &   0.04 &    0.883 \\
# vfl         &    570 &  0.039 &    0.295 \\
# ab          &   1696 &  0.039 &     1.16 \\
# dabei       &   1495 &  0.037 &    0.139 \\
# lang        &   1098 &  0.036 &    0.546 \\
# ...

# %%
tmp3 = df_shap[df_shap["count"] >= 200].sort_values("mean", ascending = True).head(20)
tmp3
# Out:
#               count   mean mean_abs     min      max    std    abs
# corona         2520 -0.145    4.127 -75.541    2.708  6.338  0.145
# million         809 -0.135    2.521   -1.48  167.864  6.117  0.135
# kind           1752 -0.132    2.167  -1.366  119.144  4.908  0.132
# sein wichtig    258 -0.126    1.029 -33.721    0.481  2.582  0.126
# mutter          362 -0.112    2.394  -1.324  230.062  7.892  0.112
# zunächst        724 -0.101    1.781 -26.572    0.996  2.862  0.101
# hinaus          295 -0.083    1.638 -44.683     0.84  3.423  0.083
# opfer           256 -0.081    0.779 -50.154    0.363  2.875  0.081
# endlich         208  -0.08    0.712 -21.277    0.332  2.006   0.08
# etwa           1040 -0.077    1.825  -1.195   26.163   2.65  0.077
# damals          401 -0.072    1.481  -0.847   41.349  2.956  0.072
# schon          2466 -0.068    1.204 -19.264    0.909  1.761  0.068
# gehen          2961 -0.067    1.451  -20.21    1.279  2.048  0.067
# ...

# %%
print(tmp3[["count", "mean", "mean_abs"]].to_latex())
# Out:
# \begin{tabular}{llll}
# \toprule
# {} & count &   mean & mean\_abs \\
# \midrule
# kind         &  1752 & -0.181 &    0.466 \\
# frau         &  1117 & -0.134 &    0.262 \\
# corona       &  2520 & -0.094 &    1.651 \\
# mutter       &   362 & -0.091 &    0.277 \\
# meist        &   468 &  -0.06 &    1.783 \\
# schreiben    &   459 & -0.052 &    0.866 \\
# mögen        &   658 &  -0.05 &    0.117 \\
# mal          &  1160 & -0.042 &    0.112 \\
# müssen       &  1734 & -0.033 &    0.248 \\
# wohl         &   426 & -0.028 &    0.197 \\
# spät         &   756 & -0.025 &    0.322 \\
# immer        &  1897 & -0.024 &    0.177 \\
# gleichen     &   308 & -0.022 &    0.061 \\
# land         &  1100 & -0.022 &    0.126 \\
# bremen       &   223 & -0.022 &    0.075 \\
# schon        &  2466 & -0.022 &    0.087 \\
# straße       &  1358 &  -0.02 &    0.457 \\
# sein wichtig &   258 &  -0.02 &     0.15 \\
# weiß         &   478 & -0.019 &    0.663 \\
# ...

# %%
df_shap[df_shap['count'].between(200, 400)].sort_values("mean_abs", ascending = False).head(20)
# Out:
#             count   mean mean_abs     min     max    std    abs
# vater         318   0.03     0.81  -4.788  29.402  2.339   0.03
# name          375 -0.013    0.772  -8.023  92.051  2.695  0.013
# tatsächlich   267  0.041    0.756 -15.512  30.971  2.029  0.041
# nie           324 -0.017    0.575 -12.068  37.933  1.662  0.017
# internet      258  0.023    0.566  -1.635  31.437  1.679  0.023
# film          239  0.022    0.554  -3.246  58.847  2.557  0.022
# häufig        268 -0.011    0.522  -4.108  44.812  1.618  0.011
# dr            207  0.026    0.498  -1.143  41.288  1.857  0.026
# studie        225  0.024    0.467 -12.604   47.75  1.983  0.024
# 2018          394      0    0.463 -11.447   4.702  1.018      0
# gelände       202 -0.001    0.432  -1.724  28.078  1.276  0.001
# dezember      352   0.02    0.429  -5.248   7.124  0.889   0.02
# grundstück    231 -0.006    0.428  -1.453  15.814  1.135  0.006
# nennen        364  -0.01    0.413  -7.507  18.835   0.95   0.01
# ...

# %%
df_shap[df_shap['count'].between(200, 4000)].sort_values("mean", ascending = False)
# Out:
#             count   mean mean_abs      min     max    std    abs
# sehen        1589  0.147    0.595   -3.089  17.376  0.925  0.147
# foto         1848  0.124     1.87 -144.566  64.937  4.327  0.124
# erklären     1426   0.11    0.753   -4.349  18.397  1.135   0.11
# 100           460  0.102     0.17  -10.649  61.199  1.736  0.102
# deutschland  1141   0.09    0.997    -6.02  45.083  1.941   0.09
# ...           ...    ...      ...      ...     ...    ...    ...
# meist         468  -0.06    1.783  -14.501  47.365  3.747   0.06
# mutter        362 -0.091    0.277   -9.399  43.895  1.113  0.091
# corona       2520 -0.094    1.651 -205.063  52.226  4.911  0.094
# frau         1117 -0.134    0.262   -28.14  63.132  1.751  0.134
# kind         1752 -0.181    0.466  -13.814  43.514  1.863  0.181
#
# [758 rows x 7 columns]

# %%
df_shap.sort_values("std", ascending = False).head(20)
# Out:
#              count   mean mean_abs      min      max     std    abs
# sein         31583  0.866   16.455  -39.666   541.94  27.351  0.866
# weiterlesen    169  0.021    2.308   -6.912  123.207   8.334  0.021
# osnabrück     2808  0.005    5.257   -28.66   61.272   6.503  0.005
# ja             726   0.03    0.743  -13.169  163.145   6.051   0.03
# heute          827  0.015    2.478  -13.568   86.463   5.356  0.015
# magazin         38   0.11    0.224   -0.278   190.96    4.98   0.11
# corona        2520 -0.094    1.651 -205.063   52.226   4.911  0.094
# lachen         119 -0.684    0.886 -143.815   85.427   4.393  0.684
# foto          1848  0.124     1.87 -144.566   64.937   4.327  0.124
# kommentar       93  0.035    1.233  -35.423    9.132   4.064  0.035
# meist          468  -0.06    1.783  -14.501   47.365   3.747   0.06
# körper          83  0.005    0.684    -1.41   77.766   3.715  0.005
# land          1100 -0.022    0.126 -210.288   15.283   3.519  0.022
# ...

# %%
df_shap_PATH = utils.OUTPUT / 'shap_values' / f'{identifier}_df_shap.tsv'

# %%
#df_shap.to_csv(df_shap_PATH, sep = "\t")

# %%
df_shap = pd.read_csv(df_shap_PATH, sep = "\t", index_col = 0)

# %%
df_shap.describe()
# Out:
#               count          mean      mean_abs           min           max  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      82.078500      0.000146      0.016406     -0.725444      2.442634
# std      369.755443      0.012766      0.189890      4.238627      9.519819
# min        0.000000     -0.684340      0.000000   -210.287950     -0.038140
# 25%       19.000000     -0.000155      0.000000     -0.225621      0.000000
# 50%       30.000000      0.000000      0.000142     -0.001441      0.000947
# 75%       64.000000      0.000000      0.004799      0.000000      1.491320
# max    31583.000000      0.866367     16.454596      0.001945    541.940400
#
#                 std           abs
# count  10000.000000  10000.000000
# mean       0.082806      0.001825
# std        0.386345      0.012636
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000733      0.000043
# 75%        0.057473      0.001181
# ...

# %%
df_shap[df_shap['count'].between(200, 3000)].sort_values("abs", ascending = False).head(20)
# Out:
#              count      mean  mean_abs         min        max       std  \
# kind          1752 -0.181008  0.466064  -13.814074  43.513730  1.863424
# sehen         1589  0.146687  0.594696   -3.088889  17.375864  0.925089
# frau          1117 -0.134293  0.261913  -28.140240  63.132260  1.750773
# foto          1848  0.124475  1.870319 -144.566000  64.937004  4.326928
# erklären      1426  0.109731  0.753242   -4.348865  18.397158  1.134954
# 100            460  0.102421  0.170195  -10.648885  61.198666  1.735929
# corona        2520 -0.094310  1.650598 -205.062850  52.225660  4.910811
# mutter         362 -0.090890  0.277393   -9.398595  43.895195  1.113224
# deutschland   1141  0.090396  0.996685   -6.019711  45.082985  1.941254
# wer            900  0.087830  1.400849  -11.498026  59.806100  3.194779
# januar         408  0.060726  0.422887  -17.378110   6.345722  1.077401
# meist          468 -0.060483  1.783133  -14.501272  47.365047  3.747185
# ...

# %%
s = nltk.corpus.stopwords.words('german')

# %%
len(s)
# Out:
# 232

# %%
"alle" in s
# Out:
# True

# %%
"ist" in s
# Out:
# True

# %%
ngrams = [ f for f in feature_names if " " in f]
bigrams = [ f for f in feature_names if list(f).count(" ") == 1]
trigrams = [ f for f in feature_names if list(f).count(" ") == 2]
fourgrams = [ f for f in feature_names if list(f).count(" ") == 3]
fivegrams = [ f for f in feature_names if list(f).count(" ") == 4]

# %%
stop = set() # those where at least ONE of the contents is a stopword
for f in feature_names:
    l = f.split(" ")
    for t in l:
        if t in s:
            stop.add(f)

# %%
len(stop)
# Out:
# 665

# %%
list(stop)[:20]
# Out:
# ['uhr sein',
#  'anweisen sein',
#  'zusammen sein',
#  'sein allerdings',
#  'sein fünf',
#  'sein neu',
#  'sein landkreis',
#  'weiter',
#  'sein 20',
#  'sein 18',
#  'diesen',
#  'alle bereich',
#  'bekennen sein',
#  'mutter sein',
#  'sein zehn',
#  'sein sieben',
#  'trotzdem sein',
#  'sein deutschland',
#  'sein osnabrück',
#  'sein freitag']

# %%
notstop = set(feature_names) - stop

# %%
len(notstop)
# Out:
# 9335

# %%
print(len(ngrams))
print(len(bigrams))
print(len(trigrams))
print(len(fourgrams))
print(len(fivegrams))

print(len(notstop))
# Out:
# 2140
# 2018
# 116
# 6
# 0
# 9335

# %%
list(notstop)[:20]
# Out:
# ['luxemburg',
#  'gebeten',
#  'tagesordnung',
#  'weiterbildung',
#  'lies',
#  'wochenend',
#  'bereitstellen',
#  '42',
#  'sechs',
#  'these',
#  'scharf',
#  'exakt',
#  'mitten',
#  'allee',
#  'ende 2019',
#  'scheidend',
#  '130',
#  'technisch',
#  'ärgern',
#  'zins']

# %%
ngrams[300:320]
# Out:
# ['antrag stellen',
#  'anweisen sein',
#  'anzeige anzeige',
#  'april 1945',
#  'april 2019',
#  'april 2020',
#  'april sein',
#  'arbeit sein',
#  'arbeiten sein',
#  'armin laschet',
#  'arminia bielefeld',
#  'art weise',
#  'artland dragons',
#  'at 10',
#  'at 11',
#  'at 12',
#  'atlas delmenhorst',
#  'aufgabe sein',
#  'aufgrund aktuell',
#  'aufgrund corona']

# %%
bigrams[:20]
trigrams[:20]
#fourgrams[:20]
# Out:
# ['000 euro sein',
#  '10 000 euro',
#  '10 30 uhr',
#  '100 000 einwohner',
#  '100 000 euro',
#  '11 30 uhr',
#  '12 30 uhr',
#  '13 30 uhr',
#  '14 18 uhr',
#  '14 30 uhr',
#  '15 000 euro',
#  '15 30 uhr',
#  '16 30 uhr',
#  '17 30 uhr',
#  '18 30 uhr',
#  '19 30 uhr',
#  '20 000 euro',
#  '20 15 uhr',
#  '20 30 uhr',
#  '200 000 euro']

# %%
df_ngrams = df_shap.loc[ngrams]

# %%
df_ngrams[df_ngrams["count"] >= 100].sort_values("mean_abs", ascending = False).head(20)
# Out:
#                      count      mean  mean_abs        min        max  \
# kommend jahr           145  0.007009  0.254023  -7.449006   4.306393
# dabei sein             179  0.002821  0.227485  -5.317046  12.135580
# sein wichtig           258 -0.019930  0.150066 -10.593446   4.962688
# osnabrück sein         101  0.008199  0.136500  -3.375925   6.611306
# landkreis osnabrück    188  0.001907  0.133088  -3.183826   3.117753
# vfl osnabrück          178 -0.018093  0.093060  -1.730939   8.506211
# darüber hinaus         208  0.009124  0.087861  -2.878744  18.490644
# sein sein              552  0.003167  0.058041  -4.397475   3.828128
# sein dabei             128  0.000991  0.048088  -3.643019   1.738776
# sein ganz              126 -0.000070  0.033036  -3.415220   3.446104
# sv meppen              145  0.002416  0.030216  -1.131020  10.623138
# sein sagen             171  0.000176  0.027459  -0.431799   6.613150
# sein gut               323  0.001200  0.013774  -3.269593   2.752227
# ...

# %%
df_notstop = df_shap.loc[notstop]
df_stop = df_shap.loc[stop]
# Out:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
df_notstop.sort_values("count", ascending = False).head(40)
df_stop.sort_values("count", ascending = False).head(40)
# Out:
#                  count      mean   mean_abs        min         max        std  \
# sein             31583  0.866367  16.454596 -39.666160  541.940400  27.351128
# alle              2257  0.011372   0.122187 -10.507567    7.510247   0.485829
# eine              1185  0.001758   0.196324  -1.667157    4.903747   0.268478
# diese              707  0.030388   0.335431  -6.669974   15.535141   0.631314
# sein sein          552  0.003167   0.058041  -4.397475    3.828128   0.244791
# sein gut           323  0.001200   0.013774  -3.269593    2.752227   0.129415
# sein schon         319  0.000965   0.002483  -0.393807    1.745048   0.031067
# sein wichtig       258 -0.019930   0.150066 -10.593446    4.962688   0.470395
# dieser             240  0.008418   0.115537  -2.111706    4.476251   0.287216
# jahr sein          232  0.000812   0.001971  -0.128077    0.606957   0.018054
# sein immer         223  0.000173   0.000311  -0.056273    0.047117   0.002002
# ...

# %%
np.mean(df_stop["mean_abs"])
# Out:
# 0.02949580030415038

# %%
np.mean(df_notstop["mean_abs"])
# Out:
# 0.015475218126134884

# %%
#shap.dependence_plot("sein", shap_values, X_dev, feature_names=feature_names)
#shap.dependence_plot("foto", shap_values, X_dev, feature_names=feature_names)
#shap.dependence_plot("corona", shap_values, X_dev, feature_names=feature_names)
#shap.dependence_plot("immer", shap_values, X_dev, feature_names=feature_names)
#shap.dependence_plot("kind", shap_values, X_dev, feature_names=feature_names)
#shap.dependence_plot("delmenhorst", shap_values, X_dev, feature_names=feature_names)
#shap.dependence_plot("mutter", shap_values, X_dev, feature_names=feature_names)


# interessant: Corona wirkt sich *negativ* aus

# %%
## get the predictions

# %%
PATH_predictions = utils.OUTPUT / "predictions" / "dev"

# %%
pred_path = identifier[:-3] + 'tsv'
print(pred_path)
# Out:
# BOW_CountVectorizer_xgboost_abs_10000_TrueTrueTrue.tsv

# %%
pred_dev = pd.read_csv(PATH_predictions / pred_path, index_col = 0, sep = '\t')

# %%
pred_dev.head()
# Out:
#                    true       pred
# articleId
# NOZ_2093706  207.678161  183.84334
# NOZ_1990893  162.958904  200.47974
# NOZ_2053403  201.110236  158.58354
# NOZ_2093781  100.634328  165.36984
# NOZ_2133782  134.182292  146.08424

# %%
st.pearsonr(pred_dev.true, pred_dev.pred)
# Out:
# (0.4996306852733526, 4.704541745816889e-229)

# %%
pred_dev = pred_dev.loc[dev_IDs] # just make sure that order ist the same as in shap_values

# %%
pred_dev["nr"] = range(len(pred_dev))

# %%
NOZ = utils.get_publisher_df("NOZ")
# Out:
# Shape of df: (36383, 31)

# %%
# append text (just for inspecting)
for id_nr, ID in enumerate(pred_dev.index):
    pred_dev.loc[ID, "article_text"] = NOZ.loc[ID, "article_text"]
    pred_dev.loc[ID, "textlength"] = NOZ.loc[ID, "nr_tokens_text_BERT"]

# %%
pred_dev.head()
# Out:
#                    true       pred  \
# articleId
# NOZ_2093706  207.678161  183.84334
# NOZ_1990893  162.958904  200.47974
# NOZ_2053403  201.110236  158.58354
# NOZ_2093781  100.634328  165.36984
# NOZ_2133782  134.182292  146.08424
#
#                                                   article_text  textlength  nr
# articleId
# NOZ_2093706  Initiative "Grün statt Grau" übt Kritik: Das g...       987.0   0
# NOZ_1990893  Heiger Scholz zu Besuch im JHD: Staatssekretär...       806.0   1
# NOZ_2053403  Pfarreiengemeinschaft gibt sich neue Regeln: S...       705.0   2
# NOZ_2093781  Erneuter Fall in Tokio: Drei Monate altes Baby...       330.0   3
# NOZ_2133782  Leichte Schnittverletzung: Radfahrer sticht Fr...       405.0   4

# %%
pred_dev.sort_values("pred", ascending=False).head()
# Out:
#                     true        pred  \
# articleId
# NOZ_2074650   364.542169  1241.92790
# NOZ_1376771   763.160305  1183.37050
# NOZ_515048   2396.707547   876.20270
# NOZ_1702941  1256.927835   854.34344
# NOZ_2130386   236.522337   754.08740
#
#                                                   article_text  textlength  \
# articleId
# NOZ_2074650  "Es gab keinen Plan B": Nico Santos wuchs als ...      2834.0
# NOZ_1376771  Schauspieler und vierfacher Vater: Wolfram Koc...      3400.0
# NOZ_515048   Gitarrist und Sänger im Interview: Farin Urlau...      2916.0
# NOZ_1702941  "Ewige Jugend" im ARD-Programm: Uwe Kockisch: ...      2701.0
# NOZ_2130386  Öfter heißt nicht besser: Neue Sex-Studie zeig...      1288.0
#
#                nr
# articleId
# NOZ_2074650  2439
# NOZ_1376771  2914
# NOZ_515048    302
# NOZ_1702941   217
# NOZ_2130386   161

# %%
pred_dev[pred_dev.pred >= 200][100:120]
# Out:
#                     true       pred  \
# articleId
# NOZ_2026442   238.107143  216.93842
# NOZ_1957756   168.096916  267.34924
# NOZ_2076687   215.500000  222.81711
# NOZ_2137252   239.214477  247.91096
# NOZ_1972799   180.223108  229.12637
# NOZ_1948580   545.322581  306.97955
# NOZ_2081303   231.222222  207.20285
# NOZ_1175255   905.885417  214.23456
# NOZ_1943886   256.282051  202.48946
# NOZ_2108999   131.940000  214.48677
# NOZ_2062689   211.423077  269.95108
# NOZ_2113083   172.274769  205.70732
# NOZ_1936563   182.276029  212.40642
# NOZ_12149     368.542553  291.07810
# NOZ_2018931   233.912134  301.05988
# NOZ_729041   1636.495575  361.70795
# NOZ_1965917   108.522399  274.08270
# NOZ_1683934   157.006897  231.95572
# NOZ_2122863   414.415385  211.43776
# NOZ_1920303   166.434211  209.78139
#
#                                                   article_text  textlength  \
# articleId
# NOZ_2026442  Warten auf die Bewährungschance: SF-Lotte-Inte...       970.0
# ...

# %%
ind = 5
ID = pred_dev.index[ind]
print(ID)
shap.force_plot(explainer.expected_value,
                shap_values[ind,:],
                X_dev[ind,:],
                feature_names=feature_names)


                #show=False,
                #matplotlib=True).savefig(f'{ID}.png', format = "png", dpi = 50, bbox_inches = 'tight')
# Out:
# NOZ_2039028
# <div id='i8GO4HMZOY2H8G2VE5WD1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
ind = 3632
print(pred_dev.iloc[ind])
shap.force_plot(explainer.expected_value,
                shap_values[ind,:],
                X_dev[ind,:],
                feature_names=feature_names
               )
# Out:
# true                                                      238.106
# pred                                                      242.549
# article_text    EU will Tattoofarben verbieten : Mark Benecke ...
# textlength                                                    744
# nr                                                           3632
# Name: NOZ_1997115, dtype: object
# <div id='iR42W75XYC9PMN8ANK8B6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
ind = 3595
print(pred_dev.iloc[ind])
shap.force_plot(explainer.expected_value,
                shap_values[ind,:],
                X_dev[ind,:],
                feature_names=feature_names
               )
# Out:
# true                                                       212.73
# pred                                                      253.083
# article_text    Wandern in Ibbenbüren : Tolle Ausblicke und au...
# textlength                                                   1265
# nr                                                           3595
# Name: NOZ_2060784, dtype: object
# <div id='iEVD7A0JNZLTVA9U71NGQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
ind = 566
print(pred_dev.iloc[ind])
shap.force_plot(explainer.expected_value,
                shap_values[ind,:],
                X_dev[ind,:],
                feature_names=feature_names
               )
# Out:
# true                                                      79.3611
# pred                                                       121.15
# article_text    Vielseitiges Programm für 2020: Kunsthalle Lin...
# textlength                                                    846
# nr                                                            566
# Name: NOZ_1961161, dtype: object
# <div id='iIW9FR18Q6ND0QW7FZFNG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
ind = 366
print(pred_dev.iloc[ind])
shap.force_plot(explainer.expected_value,
                shap_values[ind,:],
                X_dev[ind,:],
                feature_names=feature_names
               )
# Out:
# true                                                      211.423
# pred                                                      269.951
# article_text    Illegale Müllkippen in Düsternort und Hasport:...
# textlength                                                   1204
# nr                                                            366
# Name: NOZ_2062689, dtype: object
# <div id='iOECYB3XSDDZH7J8WTRK5'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# so soll man angeblich plots speichern können

#import matplotlib.pyplot as plt
#f = plt.figure()
#shap.summary_plot(rf_shap_values, X_test)
#f.savefig("/summary_plot1.png", bbox_inches='tight', dpi=600)

# %%
shap.dependence_plot("sein", shap_values, X_dev, feature_names=feature_names)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
def model_predict(data):
    if isinstance(data, list):        
        X = vectorizer.transform(data)
        X = X.toarray()
        outputs = model.predict(X)
    if isinstance(data, np.ndarray):
        outputs = model.predict(data)
    return np.array(outputs)

# %%
model_predict(["Das hier ist ein Artikel, der ist voll spannend. Geht um nen Unfall und einen Kindergarten und die neuste Mode."])
# Out:
# array([135.2923], dtype=float32)

# %%
dev_preds = model_predict(X_dev)

# %%
dev_preds = pd.DataFrame(dev_preds, index = NOZ_dev.index, columns = ["pred"])

# %%
dev_preds.head()
# Out:
#                    pred
# articleId
# NOZ_2093706  199.581390
# NOZ_1990893  178.686661
# NOZ_2053403  171.042740
# NOZ_2093781  159.735001
# NOZ_2133782  149.422134

# %%
# append text (just for inspecting)
for id_nr, ID in enumerate(dev_preds.index):
    dev_preds.loc[ID, "true"] = NOZ.loc[ID, "avgTimeOnPage"]
    dev_preds.loc[ID, "article_text"] = NOZ.loc[ID, "article_text"]
    dev_preds.loc[ID, "nr"] = int(id_nr)
    dev_preds.loc[ID, "textlength"] = NOZ.loc[ID, "nr_tokens_text_BERT"]

# %%
dev_preds.head()
# Out:
#                    pred        true  \
# articleId
# NOZ_2093706  199.581390  207.678161
# NOZ_1990893  178.686661  162.958904
# NOZ_2053403  171.042740  201.110236
# NOZ_2093781  159.735001  100.634328
# NOZ_2133782  149.422134  134.182292
#
#                                                   article_text   nr  \
# articleId
# NOZ_2093706  Initiative "Grün statt Grau" übt Kritik: Das g...  0.0
# NOZ_1990893  Heiger Scholz zu Besuch im JHD: Staatssekretär...  1.0
# NOZ_2053403  Pfarreiengemeinschaft gibt sich neue Regeln: S...  2.0
# NOZ_2093781  Erneuter Fall in Tokio: Drei Monate altes Baby...  3.0
# NOZ_2133782  Leichte Schnittverletzung: Radfahrer sticht Fr...  4.0
#
#              textlength
# articleId
# NOZ_2093706       987.0
# NOZ_1990893       806.0
# NOZ_2053403       705.0
# NOZ_2093781       330.0
# NOZ_2133782       405.0

# %%
def scatter(true, pred):
    print(len(true), true[:5])
    print(len(pred), pred[:5])
    plt.scatter(true, pred, alpha = 0.1)
    plt.xlabel('True')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(0,1000)
    plt.ylim(0,1000)
    plt.show()
    
    print("Pearson:", st.pearsonr(true, pred))
    print("Spearman:", st.spearmanr(true, pred)[0])

    print("MAE:", mean_absolute_error(true, pred))
    print("MSE:", mean_squared_error(true, pred))
    print("RAE:", utils.relative_absolute_error(pred, true))

# %%
scatter(true = dev_preds.true, pred = dev_preds.pred)
# Out:
# 3638 articleId
# NOZ_2093706    207.678161
# NOZ_1990893    162.958904
# NOZ_2053403    201.110236
# NOZ_2093781    100.634328
# NOZ_2133782    134.182292
# Name: true, dtype: float64
# 3638 articleId
# NOZ_2093706    199.581390
# NOZ_1990893    178.686661
# NOZ_2053403    171.042740
# NOZ_2093781    159.735001
# NOZ_2133782    149.422134
# Name: pred, dtype: float32
# Pearson: (0.531430549031228, 2.3433135358298573e-264)
# Spearman: 0.5695028467900277
# MAE: 58.826376264432824
# MSE: 14014.802345297527
# RAE: 82.53863144636516

# %%
identifier = f'BOW_{modeltype}_{feature_type}_{str(max_features)}'
print(identifier)
# Out:
# BOW_ridge_abs_1000

# %%
dev_preds.to_csv(utils.OUTPUT / "predictions_dev" / f'{identifier}.tsv', sep ="\t", 
                 index=True,
                 index_label="articleId")
# Out:
# BOW_xgboost_abs_1000

# %%
dev_preds = pd.read_csv(utils.OUTPUT / "predictions_dev" / f'{identifier}.tsv', sep ="\t", 
                       index_col = "articleId")

# %%
dev_preds.sort_values("pred", ascending = False).head(20) # höchste Predictions
#dev_preds.sort_values("pred", ascending = True).head(20) # niedrigste Predictions
# Out:
#                     pred         true  \
# articleId
# NOZ_2063514  1238.865752   540.107961
# NOZ_559307   1070.186175   454.701299
# NOZ_1376771  1037.806057   763.160305
# NOZ_570900    801.257985   721.244961
# NOZ_515048    799.242910  2396.707547
# NOZ_712712    752.157471  1383.452214
# NOZ_1997330   740.246026   356.842857
# NOZ_2046882   731.314606   231.781250
# NOZ_407676    649.770588  1198.602410
# NOZ_2077601   644.829966   381.940678
# NOZ_2113487   626.063530   619.506494
# NOZ_1702941   584.195756  1256.927835
# NOZ_456663    580.765192  1211.637306
# NOZ_2074650   576.373778   364.542169
# NOZ_2056597   567.384997   222.258656
# NOZ_1993054   566.251161   272.987069
# NOZ_535233    553.033182   244.353933
# NOZ_2085331   530.796783   304.953125
# NOZ_942136    525.590061  1147.906250
# NOZ_590750    513.600131  1193.448276
#
#                                                   article_text      nr  \
# articleId
# ...

# %%
ind = 2914 #1726 # 3547
shap.force_plot(explainer.expected_value,
                shap_values[ind,:],
                X_dev[ind,:],
                feature_names=feature_names
               )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-219-fcdb05cef14c> in <module>
#       3                 shap_values[ind,:],
#       4                 X_dev[ind,:],
# ----> 5                 feature_names=feature_names
#       6                )
#
# ~/miniconda3/envs/GPU/lib/python3.7/site-packages/shap/plots/_force.py in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation)
#      94
#      95     if type(shap_values) != np.ndarray:
# ---> 96         return visualize(shap_values)
#      97
#      98     # convert from a DataFrame or other types
#
# ~/miniconda3/envs/GPU/lib/python3.7/site-packages/shap/plots/_force.py in visualize(e, plot_cmap, matplotlib, figsize, show, ordering_keys, ordering_keys_time_format, text_rotation)
# ...
